# %%
import dace
import numpy as np
from dace.transformation.interstate import GPUTransformSDFG, StateFusion
from dace.transformation.dataflow import MapTiling, InLocalStorage, MapExpansion, MapCollapse
from dace.transformation.optimizer import Optimizer
from dace.transformation import helpers as xfutil

def find_map_by_param(sdfg: dace.SDFG, pname: str) -> dace.nodes.MapEntry:
    """ Finds the first map entry node by the given parameter name. """
    return next((n, state) for n, state in sdfg.all_nodes_recursive()
                if isinstance(n, dace.nodes.MapEntry) and pname in n.params)

def find_map_by_name(sdfg: dace.SDFG, name: str) -> dace.nodes.MapEntry:
    """ Finds the first map entry node by the given parameter name. """
    return next((n, state) for n, state in sdfg.all_nodes_recursive()
                if isinstance(n, dace.nodes.MapEntry) and name == n.label)

M = dace.symbol('M')
N = dace.symbol('N')
K = dace.symbol('K')

@dace.program
def matmul(A: dace.float64[M, K], B: dace.float64[K, N]):
    return A @ B
# Out:
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">
#         <script>
#         require.config({
#             paths: {
#                 "math": "https://spcl.github.io/dace/webclient/external_lib/math.min"
#             },
#             waitSeconds: 40
#           });
#         require( ["math"], x => window.math = x);
#         </script><script src="https://spcl.github.io/dace/webclient/renderer_dir/dagre.js"></script>
# <script src="https://spcl.github.io/dace/webclient/renderer_dir/global_vars.js"></script>
# <script src="https://spcl.github.io/dace/webclient/context_menu.js"></script>
# <script src="https://spcl.github.io/dace/webclient/renderer_elements.js"></script>
# <script src="https://spcl.github.io/dace/webclient/sdfg_utils.js"></script>
# <script src="https://spcl.github.io/dace/webclient/overlay_manager.js"></script>
# <script src="https://spcl.github.io/dace/webclient/renderer.js"></script>
# <link href="https://spcl.github.io/dace/webclient/sdfv.css" rel="stylesheet">

# %%
sdfg = matmul.to_sdfg()
sdfg
# Out:
# Applied 1 StateFusion.
# <div id="contents_9172061154549731447" style="position: relative; resize: vertical; overflow: auto"></div>
# <script>
#     var sdfg_9172061154549731447 = "{\n  \"type\": \"SDFG\",\n  \"attributes\": {\n    \"arg_names\": [\n      \"A\",\n      \"B\"\n    ],\n    \"constants_prop\": {},\n    \"_arrays\": {\n      \"A\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"K\",\n            \"1\"\n          ],\n          \"total_size\": \"K*M\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"K\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"B\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"K*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"K\",\n            \"N\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"__return\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"M*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"N\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      }\n    },\n    \"symbols\": {\n      \"K\": \"int32\",\n      \"M\": \"int32\",\n      \"N\": \"int32\"\n    },\n    \"instrument\": \"No_Instrumentation\",\n    \"global_code\": {\n      \"frame\": {\n        \"string_data\": \"\",\n        \"language\": \"CPP\"\n      }\n    },\n    \"init_code\": {\n      \"frame\": {\n        \"string_data\": \"\",\n        \"language\": \"CPP\"\n      }\n    },\n    \"exit_code\": {\n      \"frame\": {\n        \"string_data\": \"\",\n        \"language\": \"CPP\"\n      }\n    },\n    \"orig_sdfg\": null,\n    \"transformation_hist\": [],\n    \"name\": \"matmul\"\n  },\n  \"nodes\": [\n    {\n      \"type\": \"SDFGState\",\n      \"label\": \"BinOp_24\",\n      \"id\": 0,\n      \"collapsed\": false,\n      \"scope_dict\": {\n        \"-1\": [\n          0,\n          1,\n          2,\n          3\n        ]\n      },\n      \"nodes\": [\n        {\n          \"type\": \"AccessNode\",\n          \"label\": \"A\",\n          \"attributes\": {\n            \"access\": \"ReadOnly\",\n            \"setzero\": false,\n            \"debuginfo\": {\n              \"type\": \"DebugInfo\",\n              \"start_line\": 24,\n              \"end_line\": 24,\n              \"start_column\": 15,\n              \"end_column\": 15,\n              \"filename\": \"<ipython-input-1-ddd765aaf74f>\"\n            },\n            \"data\": \"A\",\n            \"in_connectors\": {},\n            \"out_connectors\": {}\n          },\n          \"id\": 0,\n          \"scope_entry\": null,\n          \"scope_exit\": null\n        },\n        {\n          \"type\": \"AccessNode\",\n          \"label\": \"B\",\n          \"attributes\": {\n            \"access\": \"ReadOnly\",\n            \"setzero\": false,\n            \"debuginfo\": {\n              \"type\": \" ...

# %%
sdfg.expand_library_nodes()
sdfg
# Out:
# Automatically expanded library node "_MatMult_" with implementation "specialize".
# Automatically expanded library node "_MatMult_gemm" with implementation "pure".
# <div id="contents_6224492562137818046" style="position: relative; resize: vertical; overflow: auto"></div>
# <script>
#     var sdfg_6224492562137818046 = "{\n  \"type\": \"SDFG\",\n  \"attributes\": {\n    \"arg_names\": [\n      \"A\",\n      \"B\"\n    ],\n    \"constants_prop\": {},\n    \"_arrays\": {\n      \"A\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"K\",\n            \"1\"\n          ],\n          \"total_size\": \"K*M\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"K\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"B\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"K*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"K\",\n            \"N\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"__return\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"M*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"N\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      }\n    },\n    \"symbols\": {\n      \"K\": \"int32\",\n      \"M\": \"int32\",\n      \"N\": \"int32\"\n    },\n    \"instrument\": \"No_Instrumentation\",\n    \"global_code\": {\n      \"frame\": {\n        \"string_data\": \"\",\n        \"language\": \"CPP\"\n      }\n    },\n    \"init_code\": {\n      \"frame\": {\n        \"string_data\": \"\",\n        \"language\": \"CPP\"\n      }\n    },\n    \"exit_code\": {\n      \"frame\": {\n        \"string_data\": \"\",\n        \"language\": \"CPP\"\n      }\n    },\n    \"orig_sdfg\": null,\n    \"transformation_hist\": [],\n    \"name\": \"matmul\"\n  },\n  \"nodes\": [\n    {\n      \"type\": \"SDFGState\",\n      \"label\": \"BinOp_24\",\n      \"id\": 0,\n      \"collapsed\": false,\n      \"scope_dict\": {\n        \"-1\": [\n          0,\n          1,\n          2,\n          3\n        ]\n      },\n      \"nodes\": [\n        {\n          \"type\": \"AccessNode\",\n          \"label\": \"A\",\n          \"attributes\": {\n            \"access\": \"ReadOnly\",\n            \"setzero\": false,\n            \"debuginfo\": {\n              \"type\": \"DebugInfo\",\n              \"start_line\": 24,\n              \"end_line\": 24,\n              \"start_column\": 15,\n              \"end_column\": 15,\n              \"filename\": \"<ipython-input-1-ddd765aaf74f>\"\n            },\n            \"data\": \"A\",\n            \"in_connectors\": {},\n            \"out_connectors\": {}\n          },\n          \"id\": 0,\n          \"scope_entry\": null,\n          \"scope_exit\": null\n        },\n        {\n          \"type\": \"AccessNode\",\n          \"label\": \"B\",\n          \"attributes\": {\n            \"access\": \"ReadOnly\",\n            \"setzero\": false,\n            \"debuginfo\": {\n              \"type\": \" ...

# %%
sdfg.apply_transformations(GPUTransformSDFG)
sdfg
# Out:
# Applied 2 StateFusion.
# Applied 1 GPUTransformSDFG.
# <div id="contents_3337759858094575953" style="position: relative; resize: vertical; overflow: auto"></div>
# <script>
#     var sdfg_3337759858094575953 = "{\n  \"type\": \"SDFG\",\n  \"attributes\": {\n    \"arg_names\": [\n      \"A\",\n      \"B\"\n    ],\n    \"constants_prop\": {},\n    \"_arrays\": {\n      \"A\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"K\",\n            \"1\"\n          ],\n          \"total_size\": \"K*M\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"K\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"B\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"K*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"K\",\n            \"N\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"__return\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"M*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"N\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"gpu_B\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"K*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"K\",\n            \"N\"\n          ],\n          \"transient\": true,\n          \"storage\": \"GPU_Global\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"gpu_A\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"K\",\n            \"1\"\n          ],\n          \"total_size\": \"K*M\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"K\"\n          ],\n          \"transient\": true,\n          \"storage\": \"GPU_Global\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"gpu___return\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"M*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n      ...

# %%
gemm, state = 
1

​

(sdfg, "gemm_map")
xfutil.tile(state.parent, gemm, True, True, __i0 =128, __i1 = 128, __i2 = 8)
sdfg
# Out:
# <div id="contents_6189220898886005946" style="position: relative; resize: vertical; overflow: auto"></div>
# <script>
#     var sdfg_6189220898886005946 = "{\n  \"type\": \"SDFG\",\n  \"attributes\": {\n    \"arg_names\": [\n      \"A\",\n      \"B\"\n    ],\n    \"constants_prop\": {},\n    \"_arrays\": {\n      \"A\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"K\",\n            \"1\"\n          ],\n          \"total_size\": \"K*M\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"K\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"B\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"K*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"K\",\n            \"N\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"__return\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"M*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"N\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"gpu_B\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"K*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"K\",\n            \"N\"\n          ],\n          \"transient\": true,\n          \"storage\": \"GPU_Global\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"gpu_A\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"K\",\n            \"1\"\n          ],\n          \"total_size\": \"K*M\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"K\"\n          ],\n          \"transient\": true,\n          \"storage\": \"GPU_Global\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"gpu___return\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"M*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n      ...

# %%
sdfg.apply_transformations(MapCollapse)
sdfg
# Out:
# Applied 1 MapCollapse.
# <div id="contents_818976179482315385" style="position: relative; resize: vertical; overflow: auto"></div>
# <script>
#     var sdfg_818976179482315385 = "{\n  \"type\": \"SDFG\",\n  \"attributes\": {\n    \"arg_names\": [\n      \"A\",\n      \"B\"\n    ],\n    \"constants_prop\": {},\n    \"_arrays\": {\n      \"A\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"K\",\n            \"1\"\n          ],\n          \"total_size\": \"K*M\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"K\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"B\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"K*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"K\",\n            \"N\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"__return\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"M*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"N\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"gpu_B\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"K*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"K\",\n            \"N\"\n          ],\n          \"transient\": true,\n          \"storage\": \"GPU_Global\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"gpu_A\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"K\",\n            \"1\"\n          ],\n          \"total_size\": \"K*M\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"K\"\n          ],\n          \"transient\": true,\n          \"storage\": \"GPU_Global\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"gpu___return\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"M*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n       ...
