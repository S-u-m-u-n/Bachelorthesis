# %%
import dace
from dace.transformation.interstate import GPUTransformSDFG, StateFusion
from dace.transformation.dataflow import MapTiling, InLocalStorage, MapExpansion, MapCollapse, MapReduceFusion
from dace.transformation.optimizer import Optimizer
from dace.transformation import helpers as xfutil

def find_map_by_param(sdfg: dace.SDFG, pname: str) -> dace.nodes.MapEntry:
    """ Finds the first map entry node by the given parameter name. """
    return next((n, state) for n, state in sdfg.all_nodes_recursive()
                if isinstance(n, dace.nodes.MapEntry) and pname in n.params)


def find_map_by_name(sdfg: dace.SDFG, name: str) -> dace.nodes.MapEntry:
    """ Finds the first map entry node by the given parameter name. """
    return next((n, state) for n, state in sdfg.all_nodes_recursive()
                if isinstance(n, dace.nodes.MapEntry) and name == n.label)

M = dace.symbol('M')
N = dace.symbol('N')
K = dace.symbol('K')
alpha = dace.symbol('alpha')
beta = dace.symbol('beta')

@dace.program
def matmul(A: dace.float64[M, K], B: dace.float64[K, N], C: dace.float64[M, N], alpha: dace.float64, beta: dace.float64):
    return alpha * (A @ B) + beta * C

M = 640
N = 640
K = 640
beta = 1
alpha = 1

# %%
sdfg = matmul.to_sdfg()
sdfg
# Out:
# Applied 4 StateFusion.
# <div id="contents_3175903168580608616" style="position: relative; resize: vertical; overflow: auto"></div>
# <script>
#     var sdfg_3175903168580608616 = "{\n  \"type\": \"SDFG\",\n  \"attributes\": {\n    \"arg_names\": [\n      \"A\",\n      \"B\",\n      \"C\",\n      \"alpha\",\n      \"beta\"\n    ],\n    \"constants_prop\": {},\n    \"_arrays\": {\n      \"A\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"K\",\n            \"1\"\n          ],\n          \"total_size\": \"K*M\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"K\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"B\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"K*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"K\",\n            \"N\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"C\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"M*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"N\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"alpha\": {\n        \"type\": \"Scalar\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"1\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"beta\": {\n        \"type\": \"Scalar\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"1\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"__tmp0\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"M*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"N\"\n          ],\n          \"transient\": true,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"__tmp1\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"M*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n        ...

# %%
sdfg.apply_transformations(MapReduceFusion)
sdfg
# Out:
# <div id="contents_311014061256751453" style="position: relative; resize: vertical; overflow: auto"></div>
# <script>
#     var sdfg_311014061256751453 = "{\n  \"type\": \"SDFG\",\n  \"attributes\": {\n    \"arg_names\": [\n      \"A\",\n      \"B\",\n      \"C\",\n      \"alpha\",\n      \"beta\"\n    ],\n    \"constants_prop\": {},\n    \"_arrays\": {\n      \"A\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"K\",\n            \"1\"\n          ],\n          \"total_size\": \"K*M\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"K\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"B\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"K*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"K\",\n            \"N\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"C\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"M*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"N\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"alpha\": {\n        \"type\": \"Scalar\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"1\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"beta\": {\n        \"type\": \"Scalar\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"1\"\n          ],\n          \"transient\": false,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"__tmp0\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"M*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n          ],\n          \"may_alias\": false,\n          \"alignment\": 0,\n          \"dtype\": \"float64\",\n          \"shape\": [\n            \"M\",\n            \"N\"\n          ],\n          \"transient\": true,\n          \"storage\": \"Default\",\n          \"lifetime\": \"Scope\",\n          \"location\": {},\n          \"debuginfo\": null\n        }\n      },\n      \"__tmp1\": {\n        \"type\": \"Array\",\n        \"attributes\": {\n          \"allow_conflicts\": false,\n          \"strides\": [\n            \"N\",\n            \"1\"\n          ],\n          \"total_size\": \"M*N\",\n          \"offset\": [\n            \"0\",\n            \"0\"\n         ...
